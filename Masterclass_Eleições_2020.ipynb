# %% [markdown]
# <a href="https://colab.research.google.com/github/Luansouzallo/Masterclass_Eleicoes-/blob/main/Masterclass_Elei%C3%A7%C3%B5es_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# modelagem de dados
import pandas as pd
import numpy as np


# libs gráficas
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt

#Avisos
import warnings
warnings.filterwarnings('ignore')

# Configurações no Pandas
pd.set_option('Display.max_rows', 200)
pd.set_option('Display.max_columns', 100)

# Configurações no Matplot
plt.rcParams['figure.figsize'] = (15, 6)
plt.style.use('ggplot')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # importação dos Dados

# %% [markdown]
# **Importação dos Dados**

# %%
# Dados
Base_Dados = pd.read_csv('/content/clean_data.csv')

# Dimensao
Base_Dados.shape
# Out:
# (518675, 29)

# %%
# Verificar
Base_Dados.head()
# Out:
#    Unnamed: 0  uf  type_id  codigo_tse nome_municipio  capital  codigo_ibge  \
# 0           0  AC       11        1120     ACRELÂNDIA        0      1200013
# 1           1  AC       11        1120     ACRELÂNDIA        0      1200013
# 2           2  AC       11        1120     ACRELÂNDIA        0      1200013
# 3           3  AC       11        1120     ACRELÂNDIA        0      1200013
# 4           4  AC       13        1120     ACRELÂNDIA        0      1200013
#
#    job_count elector_count  elector_presence  absentees  nominal_votes  \
# 0          1             n              7093       2076           6849
# 1          1             n              7093       2076           6849
# 2          1             s              7093       2076           6849
# 3          1             n              7093       2076           6849
# 4          9             n              7093       2076           6482
#
#    blank_votes  total_null_votes  null_votes  technical_null_votes  \
# 0           54               190         190                     0
# 1           54               190         190                     0
# 2           54               190         190                     0
# 3           54               190         190                     0
# 4           76               120         120                     0
#
#    valid_votes  nulled_votes  judically_nulled_votes  vote_count  \
# 0         6849             0                       0        7093
# 1         6849             0                       0        7093
# 2         6849             0                       0        7093
# 3         6849             0                       0        7093
# 4         6897             0                       0        7093
#
#    candidate_number   candidate_name           candidate_coligation  \
# 0                11          CAETANO  PP - PP / SOLIDARIEDADE / PSD
# 1                12   HADAMÉS WILSON                            PDT
# 2                15         OLAVINHO          MDB - PL / MDB / PSDB
# 3                90   ROSA DO EURICO              PROS - PSL / PROS
# 4             11130  PAULA CLEURIDES                             PP
#
#   candidate_vice_name candidate_vote_destination  candidate_vote_count  \
# 0          MARQUINHOS                     Válido                  2405
# 1         LUCAS NOBRE                     Válido                  1237
# 2               GRAIA                     Válido                  2638
# 3        LUIZ DO GÁS                      Válido                   569
# 4                                         Válido                     1
#
#    legend_votes       job main_party
# 0           NaN  prefeito         PP
# 1           NaN  prefeito        PDT
# 2           NaN  prefeito        MDB
# 3           NaN  prefeito       PROS
# 4         415.0  vereador         PP

# %%
# Info
Base_Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518675 entries, 0 to 518674
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Unnamed: 0                  518675 non-null  int64
#  1   uf                          518675 non-null  object
#  2   type_id                     518675 non-null  int64
#  3   codigo_tse                  518675 non-null  int64
#  4   nome_municipio              518675 non-null  object
#  5   capital                     518675 non-null  int64
#  6   codigo_ibge                 518675 non-null  int64
#  7   job_count                   518675 non-null  int64
#  8   elector_count               518675 non-null  object
#  9   elector_presence            518675 non-null  int64
#  10  absentees                   518675 non-null  int64
#  11  nominal_votes               518675 non-null  int64
#  12  blank_votes                 518675 non-null  int64
#  13  total_null_votes            518675 non-null  int64
#  14  null_votes                  518675 non-null  int64
#  15  technical_null_votes        518675 non-null  int64
#  16  valid_votes                 518675 non-null  int64
#  17  nulled_votes                518675 non-null  int64
#  18  judically_nulled_votes      518675 non-null  int64
#  19  vote_count                  518675 non-null  int64
#  20  candidate_number            518675 non-null  int64
#  21  candidate_name              518672 non-null  object
#  22  candidate_coligation        518675 non-null  object
#  23  candidate_vice_name         518675 non-null  object
#  24  candidate_vote_destination  518675 non-null  object
#  25  candidate_vote_count        518675 non-null  int64
#  26  legend_votes                500035 non-null  float64
#  27  job                         518675 non-null  object
#  28  main_party                  518675 non-null  object
# dtypes: float64(1), int64(19), object(9)
# memory usage: 114.8+ MB

# %%
# Nulos
Base_Dados.isnull().sum()
# Out:
# Unnamed: 0                        0
# uf                                0
# type_id                           0
# codigo_tse                        0
# nome_municipio                    0
# capital                           0
# codigo_ibge                       0
# job_count                         0
# elector_count                     0
# elector_presence                  0
# absentees                         0
# nominal_votes                     0
# blank_votes                       0
# total_null_votes                  0
# null_votes                        0
# technical_null_votes              0
# valid_votes                       0
# nulled_votes                      0
# judically_nulled_votes            0
# vote_count                        0
# candidate_number                  0
# candidate_name                    3
# candidate_coligation              0
# candidate_vice_name               0
# candidate_vote_destination        0
# candidate_vote_count              0
# legend_votes                  18640
# job                               0
# main_party                        0
# dtype: int64

# %%
# Campos unicos
Base_Dados.nunique()
# Out:
# Unnamed: 0                    518675
# uf                                26
# type_id                            2
# codigo_tse                      5568
# nome_municipio                  5294
# capital                            2
# codigo_ibge                     5568
# job_count                         33
# elector_count                      2
# elector_presence                4864
# absentees                       3562
# nominal_votes                   8361
# blank_votes                     1784
# total_null_votes                2194
# null_votes                      2177
# technical_null_votes             236
# valid_votes                     8402
# nulled_votes                      10
# judically_nulled_votes          1046
# vote_count                      4864
# candidate_number               20334
# candidate_name                394364
# candidate_coligation            7941
# candidate_vice_name            16997
# candidate_vote_destination         4
# candidate_vote_count            8730
# legend_votes                    1736
# job                                2
# main_party                        33
# dtype: int64

# %%
# Retirar a coluna
Base_Dados.drop( columns=['Unnamed: 0'], inplace=True)

# %%
# Verificar
Base_Dados.head()
# Out:
#    uf  type_id  codigo_tse nome_municipio  capital  codigo_ibge  job_count  \
# 0  AC       11        1120     ACRELÂNDIA        0      1200013          1
# 1  AC       11        1120     ACRELÂNDIA        0      1200013          1
# 2  AC       11        1120     ACRELÂNDIA        0      1200013          1
# 3  AC       11        1120     ACRELÂNDIA        0      1200013          1
# 4  AC       13        1120     ACRELÂNDIA        0      1200013          9
#
#   elector_count  elector_presence  absentees  nominal_votes  blank_votes  \
# 0             n              7093       2076           6849           54
# 1             n              7093       2076           6849           54
# 2             s              7093       2076           6849           54
# 3             n              7093       2076           6849           54
# 4             n              7093       2076           6482           76
#
#    total_null_votes  null_votes  technical_null_votes  valid_votes  \
# 0               190         190                     0         6849
# 1               190         190                     0         6849
# 2               190         190                     0         6849
# 3               190         190                     0         6849
# 4               120         120                     0         6897
#
#    nulled_votes  judically_nulled_votes  vote_count  candidate_number  \
# 0             0                       0        7093                11
# 1             0                       0        7093                12
# 2             0                       0        7093                15
# 3             0                       0        7093                90
# 4             0                       0        7093             11130
#
#     candidate_name           candidate_coligation candidate_vice_name  \
# 0          CAETANO  PP - PP / SOLIDARIEDADE / PSD          MARQUINHOS
# 1   HADAMÉS WILSON                            PDT         LUCAS NOBRE
# 2         OLAVINHO          MDB - PL / MDB / PSDB               GRAIA
# 3   ROSA DO EURICO              PROS - PSL / PROS        LUIZ DO GÁS
# 4  PAULA CLEURIDES                             PP
#
#   candidate_vote_destination  candidate_vote_count  legend_votes       job  \
# 0                     Válido                  2405           NaN  prefeito
# 1                     Válido                  1237           NaN  prefeito
# 2                     Válido                  2638           NaN  prefeito
# 3                     Válido                   569           NaN  prefeito
# 4                     Válido                     1         415.0  vereador
#
#   main_party
# 0         PP
# 1        PDT
# 2        MDB
# 3       PROS
# 4         PP

# %% [markdown]
# #**Análises Macros**

# %% [markdown]
# ## **Prefeitos eleitos no país**

# %%
# Campos Unicos
Base_Dados['job'].unique(),Base_Dados['elector_count'].unique()
# Out:
# (array(['prefeito', 'vereador'], dtype=object),
#  array(['n', 's'], dtype=object))

# %%
# Filtro
Query_Prefeitos = Base_Dados[
    ( Base_Dados['job'] == 'prefeito' ) &
    ( Base_Dados['elector_count'] == 's')
]

# Dimensão
Query_Prefeitos.shape
# Out:
# (5519, 28)

# %%
# Analise
Analise_01 = Query_Prefeitos.groupby(by=['main_party']).agg(
    Quantidade=('candidate_vote_count', 'count')
)

# Verificar
Analise_01.head()
# Out:
#             Quantidade
# main_party
# AVANTE              82
# CIDADANIA          141
# DC                   1
# DEM                467
# MDB                787

# %%
# Quantidade Prefeitos Eleitos
Qtd_Prefeitos_Eleitos = Analise_01['Quantidade'].sum()

Qtd_Prefeitos_Eleitos
# Out:
# 5519

# %%
# Gerado %
Analise_01['%'] = Analise_01['Quantidade'] / Qtd_Prefeitos_Eleitos * 100
Analise_01['%'] = round(Analise_01['%'], 2)

# Ordenar 
Analise_01.sort_values('Quantidade', inplace=True, ascending=False)

# Verificar 
Analise_01.head()
# Out:
#             Quantidade      %
# main_party
# MDB                787  14.26
# PP                 687  12.45
# PSD                660  11.96
# PSDB               526   9.53
# DEM                467   8.46

# %%
# Paleta de cores
sns.color_palette('magma', len(Analise_01) )
# Out:
# [(0.013708, 0.011771, 0.068667),
#  (0.04383, 0.03383, 0.141886),
#  (0.078815, 0.054184, 0.211667),
#  (0.123833, 0.067295, 0.295879),
#  (0.171713, 0.067305, 0.370771),
#  (0.232077, 0.059889, 0.437695),
#  (0.284951, 0.063168, 0.472451),
#  (0.341482, 0.080564, 0.492631),
#  (0.390384, 0.100379, 0.501864),
#  (0.445163, 0.122724, 0.506901),
#  (0.494258, 0.141462, 0.507988),
#  (0.550287, 0.161158, 0.505719),
#  (0.600868, 0.177743, 0.500394),
#  (0.658483, 0.196027, 0.490253),
#  (0.716387, 0.214982, 0.47529),
#  (0.767398, 0.233705, 0.457755),
#  (0.822926, 0.259016, 0.433573),
#  (0.868793, 0.287728, 0.409303),
#  (0.913354, 0.330052, 0.382563),
#  (0.944006, 0.377643, 0.365136),
#  (0.967671, 0.439703, 0.35981),
#  (0.981, 0.498428, 0.369734),
#  (0.990138, 0.565296, 0.395122),
#  (0.994738, 0.62435, 0.427397),
#  (0.997077, 0.690088, 0.471811),
#  (0.997228, 0.747981, 0.516859),
#  (0.99568, 0.812706, 0.572645),
#  (0.99317, 0.870024, 0.626189),
#  (0.989815, 0.934329, 0.690198)]

# %%
# Tamanho
plt.figure( figsize=(20, 6))

Paleta_Cores = sns.color_palette('magma', len(Analise_01) )

# Plot
plt.bar(Analise_01.index,
        Analise_01['Quantidade'],
        width=0.9,
        color=Paleta_Cores
        )

# Titulo
plt.title('Prefeitos Eleitos no país', loc='left', fontsize=20, color='#404040', fontweight=600)

# Labels
plt.ylabel('Quantidade de Prefeitos')
plt.xlabel('Partidos')
plt.xticks( rotation=90 )

# Ajustando escala do gráfico
plt.ylim( 0, Analise_01['Quantidade'].max() + ( Analise_01['Quantidade'].max()*0.1))

# Incluindo os dados no gráfico
for Posicao, Valor in enumerate( Analise_01['Quantidade']):
    plt.text(
        # Posição do gráfico (x, y)
        Posicao - 0.3, Valor + 10, 
        # Valor no gráfico
        Valor,
        # Paleta
        color=Paleta_Cores[Posicao],
        # Tamanho
        size=12,
        # expessura da fonte
        fontweight=700                  
    )

# Total de Eleitos
Total_Eleitos = Analise_01['Quantidade'].sum()

# Info complementar
plt.annotate(
    f'Eleitos Brasil: { Total_Eleitos}',
    xy=(0.99,0.94),
    xycoords='axes fraction',
    ha= 'right',
    va= 'center',
    color= 'green',
    fontsize=14,
    fontweight=500,
    bbox=dict( facecolor='#ffffff', edgecolor= 'green', boxstyle='round', pad=0.25),
);

# %% [markdown]
# ## **Vereadores eleitos no país**

# %%
# Filtro
Query_Vereadores = Base_Dados[
    ( Base_Dados['job'] == 'vereador' ) &
    ( Base_Dados['elector_count'] == 's')
]

# Dimensão
Query_Vereadores.shape
# Out:
# (57866, 28)

# %%
# Analise
Analise_02 = Query_Vereadores.groupby(by=['main_party']).agg(
    Quantidade=('candidate_vote_count', 'count')
)

# Verificar
Analise_02.head()
# Out:
#             Quantidade
# main_party
# AVANTE            1046
# CIDADANIA         1583
# DC                 121
# DEM               4335
# MDB               7311

# %%
# Quantidade Vereadores Eleitos
Qtd_Vereadores_Eleitos = Analise_02['Quantidade'].sum()

Qtd_Vereadores_Eleitos
# Out:
# 57866

# %%
# Gerado %
Analise_02['%'] = Analise_02['Quantidade'] / Qtd_Vereadores_Eleitos * 100
Analise_02['%'] = round(Analise_02['%'], 2)

# Ordenar 
Analise_02.sort_values('Quantidade', inplace=True, ascending=False)

# Verificar 
Analise_02.head()
# Out:
#             Quantidade      %
# main_party
# MDB               7311  12.63
# PP                6331  10.94
# PSD               5676   9.81
# PSDB              4368   7.55
# DEM               4335   7.49

# %%
# Tamanho
plt.figure(figsize=(12, 10))

# Plot das linhas
plt.hlines(
    # Dados
    y=Analise_02.index, 
    xmin=0, 
    xmax=Analise_02['Quantidade'],
    # Espessura da linha
    lw=5,
    # Paleta
    color=Paleta_Cores,
    # Transparencia
    alpha=0.5
    )

# Plot das linhas
plt.scatter(
    # Dados
    Analise_02['Quantidade'],
    Analise_02.index,
    # Tamanho do ponto
    s=100,
    # Cor
    color=Paleta_Cores,
    # Transparencia
    alpha=0.8
)

# Titulo
plt.title('Vereadores eleitos no país', loc='left', fontsize=20, color='#404040', fontweight=500);

# Total de Eleitos
Total_Eleitos = Analise_02['Quantidade'].sum()

# Info complementar
plt.annotate(
    f'Eleitos Brasil: { Total_Eleitos}',
    xy=(0.99,0.94),
    xycoords='axes fraction',
    ha= 'right',
    va= 'center',
    color= 'green',
    fontsize=14,
    fontweight=500,
    bbox=dict( facecolor='#ffffff', edgecolor= 'green', boxstyle='round', pad=0.25),
);

# %% [markdown]
# ## **Analise de Correlação**

# %%
len(Analise_01), len(Analise_02)
# Out:
# (29, 29)

# %%
# Tab
Tab_Correlacao = Analise_01['Quantidade'].reset_index()

# Cruzamento
Tab_Correlacao = pd.merge( Tab_Correlacao, Analise_02.reset_index(), on=['main_party'], how='inner')

# Ajustar
Tab_Correlacao.columns = ['Partido', 'Prefeitos', 'Vereadores', '%']

# Drop
Tab_Correlacao.drop( columns=['%'], inplace=True )

# Verificando
Tab_Correlacao.head()
# Out:
#   Partido  Prefeitos  Vereadores
# 0     MDB        787        7311
# 1      PP        687        6331
# 2     PSD        660        5676
# 3    PSDB        526        4368
# 4     DEM        467        4335

# %%
# Plot da regressão

sns.regplot(
    
    # Dados
    x=Tab_Correlacao['Prefeitos'],
    y=Tab_Correlacao['Vereadores'],

    # Intervalo de confiança para estimar a regressão
    ci = 95,

    # Cor dos pontos
    scatter_kws={
        'color' : 'blue',
        's' : 80,
        'alpha' : 0.5
    },

    # Cor da Linha
    line_kws={
        'color' : 'red',
        'alpha' : 0.2,
        'lw' : 2

    },
)

# titulo
plt.title('Prefeitos x Vereadores eleitos');

# Loop para incluir os textos

for Linha in range(0, Tab_Correlacao.shape[0] ):

  # Incluindo os valores
  plt.text(
      Tab_Correlacao['Prefeitos'][Linha] + 0.8,
      Tab_Correlacao['Vereadores'][Linha],
      Tab_Correlacao['Partido'][Linha],
      size='medium',
      color='gray',
      weight='semibold'
  )

# %% [markdown]
# # **Plot Tridimensional**

# %%
# Sumarizendo quantidade de candidatos
Quantidade_Candidados = Base_Dados.groupby( by=['main_party'] ).count().iloc[:,0:1].reset_index()

#Renomear colunas
Quantidade_Candidados.columns = ['Partido', 'Candidatos']

#Verificar
Quantidade_Candidados.head()
# Out:
#      Partido  Candidatos
# 0     AVANTE       14228
# 1  CIDADANIA       16390
# 2         DC        4385
# 3        DEM       31212
# 4        MDB       42169

# %%
Tab_Correlacao.head()
# Out:
#   Partido  Prefeitos  Vereadores
# 0     MDB        787        7311
# 1      PP        687        6331
# 2     PSD        660        5676
# 3    PSDB        526        4368
# 4     DEM        467        4335

# %%
# Cruzar
Tab_Correlacao = pd.merge( Tab_Correlacao, Quantidade_Candidados, on=['Partido'], how='inner')

#Verificando 
Tab_Correlacao.head()
# Out:
#   Partido  Prefeitos  Vereadores  Candidatos
# 0     MDB        787        7311       42169
# 1      PP        687        6331       36158
# 2     PSD        660        5676       37271
# 3    PSDB        526        4368       31011
# 4     DEM        467        4335       31212

# %%
# Correlacao
Tab_Correlacao.corr()
# Out:
#             Prefeitos  Vereadores  Candidatos
# Prefeitos    1.000000    0.990918    0.916985
# Vereadores   0.990918    1.000000    0.952979
# Candidatos   0.916985    0.952979    1.000000

# %%
# Plot Tridimensional

# Tamanho
Figura =plt.figure( figsize=(15, 8) )

# Instanciar
Eixo = Figura.add_subplot( 111, projection='3d' )

# Plot
Eixo.scatter(
    Tab_Correlacao['Prefeitos'],
    Tab_Correlacao['Vereadores'],
    Tab_Correlacao['Candidatos'],
    c= 'black',
    s= 100
)

#Rotacao
Eixo.view_init(30, 185)

# Labels
Eixo.set_xlabel('Prefeitos')
Eixo.set_ylabel('Vereadores')
Eixo.set_zlabel('Candidatos');

# %%
Figura = px.scatter_3d(
    Tab_Correlacao,
    x='Prefeitos',
    y='Vereadores',
    z='Candidatos',
    color='Partido',
    opacity=0.7,
    symbol='Partido'
)

Figura.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e305e31e-a034-4b22-8003-bae992057660" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e305e31e-a034-4b22-8003-bae992057660")) {                    Plotly.newPlot(                        "e305e31e-a034-4b22-8003-bae992057660",                        [{"hovertemplate":"Partido=MDB<br>Prefeitos=%{x}<br>Vereadores=%{y}<br>Candidatos=%{z}<extra></extra>","legendgroup":"MDB","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"MDB","scene":"scene","showlegend":true,"x":[787],"y":[7311],"z":[42169],"type":"scatter3d"},{"hovertemplate":"Partido=PP<br>Prefeitos=%{x}<br>Vereadores=%{y}<br>Candidatos=%{z}<extra></extra>","legendgroup":"PP","marker":{"color":"#EF553B","opacity":0.7,"symbol":"diamond"},"mode":"markers","name":"PP","scene":"scene","showlegend":true,"x":[687],"y":[6331],"z":[36158],"type":"scatter3d"},{"hovertemplate":"Partido=PSD<br>Prefeitos=%{x}<br>Vereadores=%{y}<br>Candidatos=%{z}<extra></extra>","legendgroup":"PSD","marker":{"color":"#00cc96","opacity":0.7,"symbol":"square"},"mode":"markers","name":"PSD","scene":"scene","showlegend":true,"x":[660],"y":[5676],"z":[37271],"type":"scatter3d"},{"hovertemplate":"Partido=PSDB<br>Prefeitos=%{x}<br>Vereadores=%{y}<br>Candidatos=%{z}<extra></extra>","legendgroup":"PSDB","marker":{"color":"#ab63fa","opacity":0.7,"symbol":"x"},"mode":"markers","name":"PSDB","scene":"scene","showlegend":true,"x":[526],"y":[4368],"z":[31011],"type":"scatter3d"},{"hovertemplate":"Partido=DEM<br>Prefeitos=%{x}<br>Vereadores=%{y}<br>Candidatos=%{z}<extra></extra>","legendgroup":"DEM","marker":{"color":"#FFA15A","opacity":0.7,"symbol":"cross"},"mode":"markers","name":"DEM","scene":"scene","showlegend":true,"x":[467],"y":[4335],"z":[31212],"type":"scatter3d"},{"hovertemplate":"Partido=PL<br>Prefeitos=%{x}<br>Vereadores=%{y}<br>Candidatos=%{z}<extra></extra>","legendgroup":"PL","marker":{"color":"#19d3f3","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"PL","scene":"scene","showlegend":true,"x":[345],"y":[3464],"z":[26611],"type":"scatter3d"},{"hovertemplate":"Partido=PDT<br>Prefeitos=%{x}<br>Vereadores=%{y}<br>Candidatos=%{z}<extra></extra>","legendgroup":"PDT","marker":{"color":"#FF6692","opacity":0.7,"symbol":"diamond"},"mode":"markers","name":"PDT","scene":"scene","showlegend":true,"x":[315],"y":[3434],"z":[26893],"type":"scatter3d"},{"hovertemplate":"Partido=PSB<br>Prefeitos=%{x}<br>Vereadores=%{y}<br>Candidatos=%{z}<extra></extra>","legendgroup":"PSB","marker":{"color":"#B6E880","opacity":0.7,"symbol":"square"},"mode":"markers","name":"PSB","scene":"scene","showlegend":true,"x":[258],"y":[3006],"z":[25227],"type":"scatter3d"},{"hovertemplate":"Partido=PTB<br>Prefeitos=%{x}<br>Vereadores=%{y}<br>Candidatos=%{z}<extra></extra>","legendgroup":"PTB","marker":{"color":"#FF97FF","opacity":0.7,"symbol":"x"},"mode":"markers","name":"PTB","scene":"scene","showlegend":true,"x":[214],"y":[2466],"z":[22153],"type":"scatter3d"},{"hovertemplate":"Partido=REPUBLICANOS<br>Prefeitos=%{x}<br>Vereadores=%{y}<br>Candidatos=%{z}<extra></extra>","legendgroup":"REPUBLICANOS","marker":{"color":"#FECB52","opacity":0.7,"symbol":"cross"},"mode":"markers","name":"REPUBLICANOS","scene":"scene","showlegend":true,"x":[213],"y":[2591],"z":[27124],"type":"scatter3d"},{"hovertemplate":"Partido=PT<br>Prefeitos=%{x}<br>Vereadores=%{y}<br>Candidatos=%{z}<extra></extra>","legendgroup":"PT","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"PT","scene":"scene","showlegend":true,"x":[194],"y":[2656],"z":[29283],"type":"scatter3d"},{"hovertemplate":"Partido=CIDADANIA<br>Prefeitos=%{x}<br>Vereadores=%{y}<br>Candidatos=%{z}<extra></extra>","legendgroup":"CIDADANIA","marker" ...
